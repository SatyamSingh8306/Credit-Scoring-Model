# %%
import pandas as pd

# %%
df = pd.read_excel("CreditWorthiness.xlsx")

# %%
cols = ['Cbal', 'Cdur', 'Chist', 'Camt', 'Edur', 'InRate', 'MSG', 'Rdur',
       'Prop', 'age', 'inPlans', 'Htype', 'NumCred', 'JobType', 'Ndepend',
       'telephone', 'foreign']

# %%
df = df[['Cbal', 'Cdur', 'Chist', 'Camt', 'Edur', 'InRate', 'MSG', 'Rdur',
       'Prop', 'age', 'inPlans', 'Htype', 'NumCred', 'JobType', 'Ndepend',
       'telephone', 'foreign']]

# %%
result={}
for col in cols:
    result[col]= df[col][0]

# %%
result
# Out:
# {'Cbal': '0 <= Rs. < 2000',
#  'Cdur': 9,
#  'Chist': 'all settled till now',
#  'Camt': 13790,
#  'Edur': '1 to 4 years',
#  'InRate': 2,
#  'MSG': 'married or widowed male',
#  'Rdur': 'less than a year',
#  'Prop': 'real estate',
#  'age': 27,
#  'inPlans': 'bank',
#  'Htype': 'own',
#  'NumCred': 1,
#  'JobType': 'employee with official position',
#  'Ndepend': 1,
#  'telephone': 'yes',
#  'foreign': 'no'}

# %%
b
# Out:
# <bound method StringMethods.extract of <pandas.core.strings.accessor.StringMethods object at 0x00000201DD6BB800>>

# %%
# ! pip install openpyxl

# %%
df.sample(3)
# Out:
#                     Cbal  Cdur                   Chist                 Cpur  \
# 497  no checking account    21  none taken/all settled  second hand vehicle
# 316  no checking account    18    all settled till now          electronics
# 383  no checking account    12    all settled till now            education
#
#       Camt                Sbal               Edur  InRate  \
# 497  49910  no savings account       1 to 4 years       1
# 316  23080          Rs. < 1000       not employed       2
# 383   7070          Rs. < 1000  more than 7 years       4
#
#                                          MSG Oparties  ...  \
# 497  divorced or separated or married female   no one  ...
# 316                  married or widowed male   no one  ...
# 383                              single male   no one  ...
#
#                                 Prop age  inPlans Htype NumCred  \
# 497  life insurance/building society  29     bank   own       2
# ...

# %%
df.shape
# Out:
# (1000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Cbal         1000 non-null   object
#  1   Cdur         1000 non-null   int64
#  2   Chist        1000 non-null   object
#  3   Cpur         1000 non-null   object
#  4   Camt         1000 non-null   int64
#  5   Sbal         1000 non-null   object
#  6   Edur         1000 non-null   object
#  7   InRate       1000 non-null   int64
#  8   MSG          1000 non-null   object
#  9   Oparties     1000 non-null   object
#  10  Rdur         1000 non-null   object
#  11  Prop         1000 non-null   object
#  12  age          1000 non-null   int64
#  13  inPlans      1000 non-null   object
#  14  Htype        1000 non-null   object
#  15  NumCred      1000 non-null   int64
#  16  JobType      1000 non-null   object
#  17  Ndepend      1000 non-null   int64
# ...

# %%
int_col = ['Cdur','Camt','InRate','age','NumCred','Ndepend']

# %%
df[int_col].corr()
# Out:
#              Cdur      Camt    InRate       age   NumCred   Ndepend
# Cdur     1.000000  0.624984  0.074749 -0.036136 -0.011284 -0.023834
# Camt     0.624984  1.000000 -0.271316  0.032716  0.020795  0.017142
# InRate   0.074749 -0.271316  1.000000  0.058266  0.021669 -0.071207
# age     -0.036136  0.032716  0.058266  1.000000  0.149254  0.118201
# NumCred -0.011284  0.020795  0.021669  0.149254  1.000000  0.109667
# Ndepend -0.023834  0.017142 -0.071207  0.118201  0.109667  1.000000

# %%
df.describe()
# Out:
#               Cdur          Camt       InRate          age      NumCred  \
# count  1000.000000    1000.00000  1000.000000  1000.000000  1000.000000
# mean     20.903000   32592.58000     2.973000    35.546000     1.407000
# std      12.058814   28227.36876     1.118715    11.375469     0.577654
# min       4.000000    2380.00000     1.000000    19.000000     1.000000
# 25%      12.000000   13535.00000     2.000000    27.000000     1.000000
# 50%      18.000000   23075.00000     3.000000    33.000000     1.000000
# 75%      24.000000   39602.50000     4.000000    42.000000     2.000000
# max      72.000000  184120.00000     4.000000    75.000000     4.000000
#
#            Ndepend
# count  1000.000000
# mean      1.155000
# std       0.362086
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000

# %%
df.isnull().sum()
# Out:
# Cbal           0
# Cdur           0
# Chist          0
# Cpur           0
# Camt           0
# Sbal           0
# Edur           0
# InRate         0
# MSG            0
# Oparties       0
# Rdur           0
# Prop           0
# age            0
# inPlans        0
# Htype          0
# NumCred        0
# JobType        0
# Ndepend        0
# telephone      0
# foreign        0
# creditScore    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# from pandas_profiling import ProfileReport
# pf = ProfileReport(df)
# pf.to_file(output_file='index.html')

# %%
cols = ['Camt','Cdur','Htype','Prop','creditScore']

# %%
df = df[cols]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['creditScore'] = le.fit_transform(df[['creditScore']])
le_h = LabelEncoder()
df['Htype'] = le_h.fit_transform(df[['Htype']])
le_p = LabelEncoder()
df['Prop'] = le_p.fit_transform(df[['Prop']])
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.preprocessing import StandardScaler
sd = StandardScaler()
import seaborn as sns
sns.boxplot(df['Camt'])
# Out:
# <Axes: ylabel='Camt'>

# %%
import numpy as np

# %%
per_25 = df['Camt'].quantile(0.25)
per_75 = df['Camt'].quantile(0.75)
iqr = per_75-per_25
df['Camt'] = np.where(df['Camt']>(per_75+(1.5*iqr)),per_75+(1.5*iqr),df['Camt'])

# %%
sns.boxplot(df['Camt'])
# Out:
# <Axes: ylabel='Camt'>

# %%
df['Camt'] = sd.fit_transform(df[['Camt']])

# %%
df.sample()
# Out:
#          Camt  Cdur  Htype  Prop  creditScore
# 143 -0.983099    12      2     2            0

# %%
x,y = df.drop(columns=['creditScore']),df['creditScore']

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm  import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
models = [RandomForestClassifier(),GradientBoostingClassifier(),DecisionTreeClassifier(),SVC(),KNeighborsClassifier()]

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
for model in models:
    print(model,end=": ")
    print(np.mean(cross_val_score(model,x,y,cv=5,scoring='accuracy')))
# Out:
# RandomForestClassifier(): 0.654
# GradientBoostingClassifier(): 0.707
# DecisionTreeClassifier(): 0.61
# SVC(): 0.694
# KNeighborsClassifier(): 0.672

# %%
from sklearn.model_selection import GridSearchCV

# %%
paramameter= {
    'n_estimators':[300,250,400]

}

# %%
gd = GridSearchCV(RandomForestClassifier(),param_grid=paramameter)

# %%
gd.fit(x,y)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'n_estimators': [300, 250, 400]})

# %%
gd.best_score_
# Out:
# 0.663

# %%
gd.best_params_
# Out:
# {'n_estimators': 250}

# %%
gd_param = {
    'n_estimators':[30,40,50],
    'learning_rate':[0.3,0.1,.2,0.5]
}

# %%
gc_gd = GridSearchCV(GradientBoostingClassifier(),param_grid=gd_param)

# %%
gc_gd.fit(x,y)
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.3, 0.1, 0.2, 0.5],
#                          'n_estimators': [30, 40, 50]})

# %%
gc_gd.best_score_
# Out:
# 0.71

# %%
gc_gd.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 30}

# %%
trf1= [('gd',GradientBoostingClassifier(learning_rate=0.2,n_estimators=40)),('scv',SVC()),('rf',RandomForestClassifier(n_estimators=400))]

# %%
from sklearn.ensemble import VotingClassifier
vc = VotingClassifier(estimators=trf1,n_jobs=-1)

# %%
np.mean(cross_val_score(vc,x,y,scoring='accuracy',cv=5))
# Out:
# 0.704
