# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel("CreditWorthiness.xlsx")

# %%
df.sample(5)['JobType']
# Out:
# 29     employee with official position
# 948                 resident unskilled
# 346    employee with official position
# 785    employee with official position
# 803                 resident unskilled
# Name: JobType, dtype: object

# %%
# ! pip install openpyxl

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Cbal         1000 non-null   object
#  1   Cdur         1000 non-null   int64
#  2   Chist        1000 non-null   object
#  3   Cpur         1000 non-null   object
#  4   Camt         1000 non-null   int64
#  5   Sbal         1000 non-null   object
#  6   Edur         1000 non-null   object
#  7   InRate       1000 non-null   int64
#  8   MSG          1000 non-null   object
#  9   Oparties     1000 non-null   object
#  10  Rdur         1000 non-null   object
#  11  Prop         1000 non-null   object
#  12  age          1000 non-null   int64
#  13  inPlans      1000 non-null   object
#  14  Htype        1000 non-null   object
#  15  NumCred      1000 non-null   int64
#  16  JobType      1000 non-null   object
#  17  Ndepend      1000 non-null   int64
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder

# %%
for i,item in enumerate(cols):
    print(i,item)
# Out:
# 0 Cbal
# 1 Cdur
# 2 Chist
# 3 Camt
# 4 Edur
# 5 InRate
# 6 MSG
# 7 Rdur
# 8 Prop
# 9 age
# 10 inPlans
# 11 Htype
# 12 NumCred
# 13 JobType
# 14 Ndepend
# 15 telephone
# 16 foreign

# %%
cols
# Out:
# Index(['Cbal', 'Cdur', 'Chist', 'Camt', 'Edur', 'InRate', 'MSG', 'Rdur',
#        'Prop', 'age', 'inPlans', 'Htype', 'NumCred', 'JobType', 'Ndepend',
#        'telephone', 'foreign'],
#       dtype='object')

# %%
trf1 = ColumnTransformer(transformers=[
    ('label',LabelEncoder(),['Prop','inPlans','JobType','foreign','telephone']),
    ('Cbal',OrdinalEncoder(categories=[['no checking account',' Rs. < 0','0 <= Rs. < 2000','Rs. >=2000']]),['Cbal']),
    ('chist',OrdinalEncoder(categories=[['all settled till now','dues not paid earlier','all settled','none taken/all settled']]),['Chist']),
    ('edur',OrdinalEncoder(categories=[['1 to 4 years','more than 7 years','4 to 7 years','less than 1 year','not employed']]),['Edur']),
    ('msg',OrdinalEncoder(categories=[['single male','divorced or separated or married female','married or widowed male','divorced or separated male']]),['MSG']),
    ('Rdur', OrdinalEncoder(categories=[['more than 3 years','1 to 2 years','2 to 3 years','less than a year']]),['Rdur']),
    ('htype',OrdinalEncoder(categories=[['own','pays rent','free']]),['Htype'])
],remainder='passthrough')

# %%
oe_cba = OrdinalEncoder(categories=[['no checking account',' Rs. < 0','0 <= Rs. < 2000','Rs. >=2000']])
df['Cbal'] = oe_cba.fit_transform(df[['Cbal']])

# %%
oe_chist = OrdinalEncoder(categories=[['all settled till now','dues not paid earlier','all settled','none taken/all settled']])
df['Chist'] = oe_chist.fit_transform(df[['Chist']])

# %%
oe_edur = OrdinalEncoder(categories=[['1 to 4 years','more than 7 years','4 to 7 years','less than 1 year','not employed']])
df['Edur'] = oe_edur.fit_transform(df[['Edur']])

# %%
oe_msg = OrdinalEncoder(categories=[['single male','divorced or separated or married female','married or widowed male','divorced or separated male']])
df['MSG'] = oe_msg.fit_transform(df[['MSG']])

# %%
oe_rdur = OrdinalEncoder(categories=[['more than 3 years','1 to 2 years','2 to 3 years','less than a year']])
df['Rdur'] = oe_rdur.fit_transform(df[['Rdur']])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['Prop'] = le.fit_transform(df[['Prop']])
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
le_p = LabelEncoder()
df['inPlans'] = le_p.fit_transform(df[['inPlans']])
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
oe_h =OrdinalEncoder(categories=[['own','pays rent','free']])
df['Htype'] = oe_h.fit_transform(df[['Htype']])

# %%
le_j = LabelEncoder()
df['JobType'] = le_j.fit_transform(df[['JobType']])
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
le_t = LabelEncoder()
df['telephone'] = le_t.fit_transform(df[['telephone']])
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
le_f = LabelEncoder()
df['foreign'] = le_f.fit_transform(df[['foreign']])
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
le_f = LabelEncoder()
df['creditScore'] = le_f.fit_transform(df[['creditScore']])
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df.sample()
# Out:
#      Cbal  Cdur  Chist         Cpur   Camt        Sbal  Edur  InRate  MSG  \
# 397   1.0    12    0.0  new vehicle  33740  Rs. < 1000   1.0       3  0.0
#
#     Oparties  ...  Prop  age  inPlans  Htype  NumCred  JobType  Ndepend  \
# 397   no one  ...     1   35        1    2.0        1        1        1
#
#      telephone  foreign  creditScore
# 397          1        0            0
#
# [1 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Cbal', 'Cdur', 'Chist', 'Cpur', 'Camt', 'Sbal', 'Edur', 'InRate',
#        'MSG', 'Oparties', 'Rdur', 'Prop', 'age', 'inPlans', 'Htype', 'NumCred',
#        'JobType', 'Ndepend', 'telephone', 'foreign', 'creditScore'],
#       dtype='object')

# %%
for i,item in enumerate()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Cbal         1000 non-null   float64
#  1   Cdur         1000 non-null   int64
#  2   Chist        1000 non-null   float64
#  3   Cpur         1000 non-null   object
#  4   Camt         1000 non-null   int64
#  5   Sbal         1000 non-null   object
#  6   Edur         1000 non-null   float64
#  7   InRate       1000 non-null   int64
#  8   MSG          1000 non-null   float64
#  9   Oparties     1000 non-null   object
#  10  Rdur         1000 non-null   float64
#  11  Prop         1000 non-null   int32
#  12  age          1000 non-null   int64
#  13  inPlans      1000 non-null   int32
#  14  Htype        1000 non-null   float64
#  15  NumCred      1000 non-null   int64
#  16  JobType      1000 non-null   int32
#  17  Ndepend      1000 non-null   int64
# ...

# %%
df.drop(columns=['Sbal','Oparties','Cpur'],inplace=True)

# %%
def outlier(col): 
    per_25 = df[col].quantile(0.25)
    per_75 = df[col].quantile(0.75)
    iqr = per_75-per_25
    df[col] = np.where(df[col]>(per_75+(1.5*iqr)),per_75+(1.5*iqr),df[col])

# %%
outlier('Camt')
# outlier('age')
# outlier('NumCred')
# outlier('Ndepend')
# outlier('Cdur')

# %%
df['Cdur'].skew()
# Out:
# 1.094184171555542

# %%
df.sample()
# Out:
#      Cbal  Cdur  Chist     Camt  Edur  InRate  MSG  Rdur  Prop  age  inPlans  \
# 766   1.0    18    1.0  39540.0   1.0       1  1.0   0.0     3   33        0
#
#      Htype  NumCred  JobType  Ndepend  telephone  foreign  creditScore
# 766    1.0        3        1        1          1        0            0

# %%
from sklearn.preprocessing import StandardScaler
sd = StandardScaler()
df['Camt'] = sd.fit_transform(df[['Camt']])

# %%
x,y = df.drop(columns=['creditScore']),df['creditScore']

# %%
cols = x.columns

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm  import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
models = [RandomForestClassifier(),GradientBoostingClassifier(),DecisionTreeClassifier(),SVC(),KNeighborsClassifier()]

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
for model in models:
    print(model,end=": ")
    print(np.mean(cross_val_score(model,x,y,cv=5,scoring='accuracy')))
# Out:
# RandomForestClassifier(): 0.742
# GradientBoostingClassifier(): 0.7750000000000001
# DecisionTreeClassifier(): 0.6900000000000001
# SVC(): 0.6960000000000001
# KNeighborsClassifier(): 0.672

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
gb = GradientBoostingClassifier()
gb.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,gb.predict(x_test))
# Out:
# 0.785

# %%
import pickle as pkl
pkl.dump(gb,open('model.pkl','wb'))

# %%
from xgboost import XGBClassifier

np.mean(cross_val_score(XGBClassifier(),x,y,cv=5,scoring='accuracy'))
# Out:
# 0.738

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_xg = {
    'max_depth':[10,30,40,50,60],
    'learning_rate':[0.1,0.05,0.3,0.4,0.5,0.7],
    'n_estimators':[40,50,60,80,100],
    'num_parallel_tree':[1,2,3,4,5,6]
}

# %%
xg_gd = GridSearchCV(XGBClassifier(),param_grid=param_xg,n_jobs=-1)

# %%
xg_gd.fit(x,y)
# Out:
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_b...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
# ...

# %%
xg_gd.best_score_
# Out:
# 0.768

# %%
xg_gd.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 10,
#  'n_estimators': 100,
#  'num_parallel_tree': 1}

# %%
paramameter= {
    'n_estimators':[300,250,400],
    'max_depth':[5,6,7,8,9,10],
    'bootstrap':[False,True]

}

# %%
gd = GridSearchCV(RandomForestClassifier(),param_grid=paramameter)

# %%
gd.fit(x,y)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [False, True],
#                          'max_depth': [5, 6, 7, 8, 9, 10],
#                          'n_estimators': [300, 250, 400]})

# %%
gd.best_score_
# Out:
# 0.762

# %%
gd.best_params_
# Out:
# {'bootstrap': True, 'max_depth': 9, 'n_estimators': 250}

# %%
gd_param = {
    'n_estimators':[30,40,50],
    'learning_rate':[0.3,0.1,.2,0.5],
    'max_depth':[10,20,30,40,50],
    'subsample':[0.2,0.1,0.3]
}

# %%
gc_gd = GridSearchCV(GradientBoostingClassifier(),param_grid=gd_param,n_jobs=-1)

# %%
gc_gd.fit(x,y)
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.1, 0.2, 0.5],
#                          'max_depth': [10, 20, 30, 40, 50],
#                          'n_estimators': [30, 40, 50],
#                          'subsample': [0.2, 0.1, 0.3]})

# %%
gc_gd.best_score_
# Out:
# 0.75

# %%
gc_gd.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 20, 'n_estimators': 30, 'subsample': 0.3}

# %%
param_dt = {
    "max_depth":[20,30,40,50],
    'splitter':['best','random'],
    'criterion':['gini', 'entropy', 'log_loss'],
    'min_samples_leaf':[0.1,0.05,0.2,.15,0.5],
    'min_samples_split':[0.2,0.4,0.6]


}

# %%
gsv = GridSearchCV(DecisionTreeClassifier(),param_grid=param_dt)

# %%
gsv.fit(x,y)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [20, 30, 40, 50],
#                          'min_samples_leaf': [0.1, 0.05, 0.2, 0.15, 0.5],
#                          'min_samples_split': [0.2, 0.4, 0.6],
#                          'splitter': ['best', 'random']})

# %%
gsv.best_params_
# Out:
# {'criterion': 'log_loss',
#  'max_depth': 40,
#  'min_samples_leaf': 0.1,
#  'min_samples_split': 0.4,
#  'splitter': 'random'}

# %%
gsv.best_score_
# Out:
# 0.7219999999999999

# %%
trf1= [('gd',GradientBoostingClassifier()),('dt',XGBClassifier(max_depth=10,n_estimators=100,learning_rate=0.05,num_parallel_tree=1)),('rf',RandomForestClassifier(n_estimators=250,max_depth=9,bootstrap=True)),('svc',SVC())]

# %%
from sklearn.ensemble import BaggingClassifier
bag1 = BaggingClassifier(estimator=RandomForestClassifier(bootstrap=True,max_depth=10,n_estimators=400),n_estimators=7)
bag2 = BaggingClassifier(estimator=GradientBoostingClassifier(),n_estimators=1)
bag3=BaggingClassifier(estimator=DecisionTreeClassifier(max_depth=20,min_samples_leaf=0.05,min_samples_split=0.3,splitter='random',criterion='entropy'),n_estimators=5)

# %%
np.mean(cross_val_score(bag2,x,y,scoring='accuracy',n_jobs=-1,cv=5))
# Out:
# 0.7310000000000001

# %%
param_bag = [('bag1',bag1),('bag2',bag2),('bag3',bag3)]

# %%
from sklearn.ensemble import VotingClassifier
vc = VotingClassifier(estimators=trf1,n_jobs=-1)

# %%
np.mean(cross_val_score(vc,x,y,scoring='accuracy',cv=2))
# Out:
# 0.744

# %%
from sklearn.ensemble import StackingClassifier
sc = StackingClassifier(estimators=trf1)

# %%
np.mean(cross_val_score(sc,x,y,cv=5,n_jobs=-1,scoring='accuracy'))
# Out:
# 0.764
